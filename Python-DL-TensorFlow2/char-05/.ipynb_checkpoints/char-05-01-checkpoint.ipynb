# %% [markdown]
# # 第5章 可视化
# ## 5.1 matplotlib简介
#  matplotlib 是 Python 中最著名的2D绘图库，它提供了和 matlab 相似的 API，十分适合交互式绘图，简单明了，功能强大，而且可以方便地将它作为绘图控件，嵌入 GUI 应用程序中。下面我们进入matplotlib的世界，开始我们的数据可视化之旅。

# %% [markdown]
# ### 5.1.1 matplotlib中的基本概念
#    Python的安装我们建议使用Anaconda安装，很多包都在Anaconda安装包中，如matplotlib、NumPy、Pandas、Sklearn等,并且后续的更新维护也非常方便。
#    在进行绘制我们的第一个图形之前，我们来看几个matplotlib里面非常重要的概念，掌握了这些概念能帮助我们快速的理解matplotlib的各种API以及能让你和你的同事使用一种大家都能听得懂的语言以及术语进行沟通。

# %% [raw]
# Matplotlib图形参数设置坐标图绘图（）主要参数配置详细说明及示例说明
# 1.导入绘图相关模块;
# 2.生成数据;
# 3.plot绘制图形，（选 - 线条设置）设置线linestyle或标记marker;
# 4.（选 - 坐标轴设置 - 添加坐标标签）给x轴添加标签xlabel和y轴添加标签ylabel;
# 5.（选 - 坐标轴设置 - 添加坐标刻度）设置x轴的刻度xlim()和y轴的刻度ylim();
# 6.（选 - 图例设置label）设置图例legend();
# 7.输出图形show()。

# %%
# 导入绘图相关模块
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# 生成数据
x = np.arange(0, 20, 1)
y1 = (x-3)**2 + 1
y2 = (x+5)**2 + 8

# 设置线的颜色、线宽、样式
plt.plot(x, y1, linestyle='-', color='b', linewidth=5.0, label='convert A')
# 添加点，设置点的样式、颜色、大小
plt.plot(x, y2, marker='o', color='r', markersize=10, label='convert B')

# 给x轴加上标签
plt.xlabel('x', size=15)

# 给y轴加上标签
plt.ylabel('y', size=15, rotation=90, horizontalalignment='right', verticalalignment='center')

# 设置x轴的刻度
plt.xlim(0, 20)
# 设置y轴的刻度
plt.ylim(0, 400)

# 设置图例
plt.legend(labels=['A', 'B'], loc='upper left', fontsize=15)

# 输出图形
plt.show()

# %% [markdown]
# 图5-1 使用matplotlib对数据进行可视化
# 也可以把图5-1 拆成两个图

# %%
plt.subplot(1, 2, 1) # 画板包含1行2列子图，当前画在第一行第一列图上
# 设置线的颜色、线宽、样式
plt.plot(x, y1, linestyle='-', color='b', linewidth=5.0, label='convert A')

plt.subplot(1, 2, 2) # 画板包含1行2列子图，当前画在第一行第二列图上
# 添加点，设置点的样式、颜色、大小
plt.plot(x, y2, marker='o', color='r', markersize=10, label='convert B')
plt.show()

# %% [markdown]
# ### 5.1.2 使用matplotlib绘制图表
# matplotlib能绘制出各种各样的图表，开发人员需要根据展示的数据的格式、内容以及要用图表来达到的效果来选择合适的图形种类。下面我们通过在日常工作中最常用的4种图表来做一个演示。

# %% [markdown]
# 1、柱状图
#  柱状图用一系列高度不等的纵向条纹或者线段直观的显示统计报告来帮助人们理解数据的分布情况，绘制柱状图，我们可以使用plt.bar(x，y，tick_label)，给出x，y坐标值，同时给出x坐标轴上对应刻度的含义等，具体例子。

# %%
import matplotlib.pyplot as plt

ages = [5, 20, 15, 25, 10]
labels = ['Tom', 'Dick', 'Harry', 'Slim', 'Jim']

plt.bar(range(len(ages)), ages, tick_label=labels)
plt.show()

# %% [markdown]
# 2、折线图
# 折线图通常用来显示随时间而变化的连续的数据，它非常适合用于提现在相等时间间隔下数据的趋势。比如，一个系统从2010开始到2020每年的注册人数。绘制折线图我们可以使用plt.plot()， 下面我们用折线图来显示系统注册人数的变化情况。

# %%
import matplotlib.pyplot as plt
import numpy as np

years = range(2010, 2020)
num_of_reg = np.random.randint(1000, 2000, 10)

plt.plot(years, num_of_reg)
plt.xticks(years)
plt.show()

# %% [markdown]
# 从上图我们可以直观的看到，系统的注册人数在2013年进入了一个谷值，而2012和2015是峰值。

# %% [markdown]
# 3、饼图
# 饼图常常用来显示一个数据系列中各项的大小以及各项在整体中的占比，比如我们可以用下面的饼图来展示各人的月收入，并显示各个分类项目占总体的比例。

# %%
import matplotlib.pyplot as plt
import numpy as np

incomings = [18882, 8543, 20012, 6311, 10000] # 各人的月收入

plt.pie(incomings, labels=labels, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# 4、散点图
# 散点图是指在回归分析中，数据点在坐标系平面上的分布图，它表示因变量随自变量而变化的大致趋势，根据其中的关系可以选择合适的函数对数据点进行拟合。下面我们展示一张身高和体重关系的散点图：

# %%
import matplotlib.pyplot as plt

heights = [110, 120, 130, 140, 150, 160, 165, 167, 169, 172, 173, 173, 175]
weights = [60,  62,  65,  67,  68,  69,  69,  72, 71,   73,  73, 71, 71]

#c指明标记颜色，s说明标记大小，marker指明标记形状
plt.scatter(heights, weights, c='b',s=100, marker='o')
plt.show()

# %% [markdown]
# 除了以上我们介绍的4种图形，matplotlib还可以绘制其他图形，比如线箱图，极限图，气泡图等，感兴趣的小伙伴可以自行查阅matplotlib的网站或者源代码。

# %% [markdown]
# ### 5.1.3 使用rcParams
# rcParams是matplotlib存放图表全局变量，我们可以用它来设置全局的图表属性，当然在进行具体图表绘制的时候，我们可以对全局变量进行覆盖。下面介绍几个常用的全局变量。
# 如果想在图表中显示中文内容，比如显示中文标题，需要在matplotlib的全局变量rcParams里进行设置。

# %% [markdown]
# 1）没说明rcParams属性

# %%
import matplotlib.pyplot as plt

x=np.arange(-10,11)
y=x**2
plt.plot(x,y)
plt.title("抛物线")
plt.xlabel("x坐标轴")
plt.ylabel("y坐标轴")
plt.show()

plt.show()
# Out:
# C:\Users\wumgapp\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 25243 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wumgapp\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 29289 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wumgapp\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 32447 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wumgapp\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22352 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\wumgapp\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 26631 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %% [markdown]
# 上图中中文标题没有输出出来，随机的变成了几个方框。通过rcParams设置文字属性即可。

# %%
plt.rcParams['font.sans-serif']=['SimHei']
# 以下适用用mac系统
# plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']
plt.rcParams['axes.unicode_minus'] = False 

plt.plot(x,y,color="blue",label="y=x**2")
plt.title("抛物线")
plt.xlabel("x坐标轴")
plt.ylabel("y坐标轴")
plt.show()

# %% [markdown]
# 更多关于rcParams可以设置的参数请参照matplotlib官网:   https://matplotlib.org/stable/api/matplotlib_configuration_api.html#matplotlib.RcParams

# %% [markdown]
# ## 5.2 Pyecharts 简介
# 做过前端开发的朋友肯定不陌生，我们现在使用的比较广范的几个Javascript图表绘制工具中有一个是由百度开源，然后捐献给Apache基金会的项目，叫做eCharts。它和ChartJS一样因为提供良好的交互性、可以绘制丰富种类的图形并且拥有漂亮的外表而受到广大前端开发人员的喜欢。
# 我们接下来要介绍的pyecharts是python版本的eCharts。 相比较于经典的matplotlib，pyecharts在保证了易用以及简洁的基础上可以让开发人员绘制出种类更加丰富（比如3D，和地图模块的集成），样式更加新颖的图表并且有一定的交互性。Python爱上了eCharts， 所以有了pyecharts。

# %% [markdown]
# ### 5.2.1 安装
#
# pyecharts 是一个用于生成 Echarts 图表的类库。echarts 是百度开源的一个数据可视化JS 库，主要用于数据可视化。pyecharts就是由Echarts 和Python组合而成，其官网为：https://pyecharts.org/
# pyecharts有两个大的版本，v0.5.x 以及 v1.x，其中
# v0.5.x 支持 python2.7 以及python3.4
# v1.x 支持python3.6以后的版本
# v0.5版本已经不再维护，并且相信大多数公司已经升级到python3.7及以后的版本，我们这里只介绍1.x的版本，并且以最新版v1.9为基础进行讲解。
# 大家可以选择通过源码安装或者pip安装， 我们这里以pip安装为例：

# %% [markdown]
# <font size=5 color=blue >pip install pyecharts</font>

# %% [markdown]
# ### 5.2.2 绘制图表
# 我们先来用一个简单的例子让读者直观的感受下pyecharts是怎样进行绘图以及它的便利性和优雅

# %%
from pyecharts.charts import Bar
from pyecharts import options

bar = (
    Bar()
    .add_xaxis(["鱼钩", "防晒用品", "鱼饵", "鱼线", "钓箱", "鱼竿"])
    .add_yaxis("2020", [5, 20, 36, 10, 75, 90])
    .add_yaxis("2021", [15, 6, 45, 20, 35, 66])
    .set_global_opts(title_opts=options.TitleOpts(title="苏州某渔具公司", subtitle='销售金额（万元）'))
)

bar.render_notebook() # 运行在jupyter notebook 环境下
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7935fd3474934eac8c22eccbac6dd6a0" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7935fd3474934eac8c22eccbac6dd6a0 = echarts.init(
#                     document.getElementById('7935fd3474934eac8c22eccbac6dd6a0'), 'white', {renderer: 'canvas'});
#                 var option_7935fd3474934eac8c22eccbac6dd6a0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# 上述代码显示了苏州XX渔具店2020以及2021年各种子品类的销售金额。 首先我们创建了一个Bar类型的图表，添加了X轴（add_xaxis）来代表各种品类，之后添加了两个Y轴的数据（add_yaxis）来代表2020以及2021的业绩，为了让图表更加容易理解，我们增加了标题以及副标题（title以及subtitle）。绘制出的图形如下

# %% [markdown]
# 1、仪表盘(Gauge)
# 我们第一个例子来模拟汽车的仪表盘，仪表盘上显示这辆汽车的最高时速，以及当前行驶速度，汽车仪表盘还会使用醒目的红色提醒驾驶员不要超速行驶，我们把这些信息一并添加到我们需要绘制的图形里面。

# %%
from pyecharts import options as opts
from pyecharts.charts import Gauge

dashboard = (
    Gauge()
    .add(
        series_name = "当前车速",
        data_pair= [("", 88)], min_=0, max_=240, split_number=12,  # 当前时速为88， 最低0km/h 最高 240km/h, 分为12段
        detail_label_opts=opts.LabelOpts(formatter="{value}km/h"), # 显示格式
        axisline_opts=opts.AxisLineOpts(
            linestyle_opts=opts.LineStyleOpts(
                color=[(0.83, "#37a2da"), (1, "red")], width=20   # 超过240km/h的0.83后，仪表板变成红色，以警示
            )
        ),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="汽车仪表盘"),
        legend_opts=opts.LegendOpts(is_show=False),
    )
)

dashboard.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="43927286e43d4d778c91028bb1cde956" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_43927286e43d4d778c91028bb1cde956 = echarts.init(
#                     document.getElementById('43927286e43d4d778c91028bb1cde956'), 'white', {renderer: 'canvas'});
#                 var option_43927286e43d4d778c91028bb1cde956 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# 大家可以从上图看到，仪表盘图形(Gauge)非常适合展示进度或者占比信息，通常我们会把几个仪表盘图形组合成一个组合图表进行展示，这样能让使用者对全局的信息有个快速的了解。不如，我们可以用几个仪表盘图形展示我们集群里面各个节点的健康状态，它们的CPU的使用率，IO的吞吐是不是在一个可承受的范围内等等。

# %% [markdown]
# 2、地理坐标系(Geo)
# ​ 这几年，各大app推出一个显示用户出行轨迹的应用广受各位旅游达人以及飞人的喜欢，在一张中国地图或者世界地图上，用箭头代表自己的飞行路径，线段的粗细代表了飞行这条航线的频率，让用户对自己过去一年的行踪有个直观的认识，也当做是在朋友圈凡尔赛的资料。接下来，我们用pyecharts来大概模拟这个功能。

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.globals import ChartType, SymbolType

c = (
    Geo()
    .add_schema(maptype="china")
    .add(
        "",
        [("上海", 1)],
        type_=ChartType.EFFECT_SCATTER,
        color="green",
    )
    .add(
        "",
        [("北京", 11), ("大连", 3), ("西安", 4), ("重庆", 2), ("西藏", 4)],
        type_=ChartType.EFFECT_SCATTER,
        color="red",
    ) # 以下我们用两个城市绘制带有箭头的连线
    .add(
        "",
        [("上海", "北京")],
        type_=ChartType.LINES,
        effect_opts=opts.EffectOpts(
            symbol=SymbolType.ARROW, symbol_size=11, color="blue"  # 用symbol_size指定连线的宽度，以代表飞行的频率
        ),
        linestyle_opts=opts.LineStyleOpts(curve=0.2),
    )
    .add(
        "",
        [("上海", "大连")],
        type_=ChartType.LINES,
        effect_opts=opts.EffectOpts(
            symbol=SymbolType.ARROW, symbol_size=3, color="blue"
        ),
        linestyle_opts=opts.LineStyleOpts(curve=0.2),
    )
    .add(
        "",
        [("上海", "西安")],
        type_=ChartType.LINES,
        effect_opts=opts.EffectOpts(
            symbol=SymbolType.ARROW, symbol_size=4, color="blue"
        ),
        linestyle_opts=opts.LineStyleOpts(curve=0.2),
    ) 
    .add(
        "",
        [("上海", "重庆")],
        type_=ChartType.LINES,
        effect_opts=opts.EffectOpts(
            symbol=SymbolType.ARROW, symbol_size=2, color="blue"
        ),
        linestyle_opts=opts.LineStyleOpts(curve=0.2),
    )
     .add(
        "",
        [("上海", "西藏")],
        type_=ChartType.LINES,
        effect_opts=opts.EffectOpts(
            symbol=SymbolType.ARROW, symbol_size=4, color="blue"
        ),
        linestyle_opts=opts.LineStyleOpts(curve=0.2),
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="7fb62300d4ef4d1b9adcc921ba6fbfdf" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_7fb62300d4ef4d1b9adcc921ba6fbfdf = echarts.init(
#                     document.getElementById('7fb62300d4ef4d1b9adcc921ba6fbfdf'), 'white', {renderer: 'canvas'});
#                 var option_7fb62300d4ef4d1b9adcc921ba6fbfdf = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "red",
#         "green",
#         "#c23531",
# ...

# %% [markdown]
# pyecharts内嵌了中国以及各个省份的矢量图，可以方便的绘制出你想要的区域，使用者可以通过使用坐标或者城市名称的形式标定出具体的位置，进而用不同的颜色代表特殊的含义。

# %% [markdown]
# ## 5.3 TensorBoard简介
#
# 在我们学习神经网络和使用TensorFlow的大多数时候，大多数人都会感觉很吃力，因为整个过程不可见。我们很难理清楚神经网络内部的结构，以及数据的流转情况，这给神经网络原理的理解和进一步使用带来了很大的挑战。TensorBoard就是为了解决整个问题而研发出来，它是TensorFlow内置的一个可视化工具，它利用TensorFlow运行时所产生的日志文件可视化指标，如培训和验证数据的损失和准确性、权重和偏差、模型图等，从而极大地帮助我们进行调试和优化等工作。
# 	那么，我们应该如何使用TensorBoard呢？首先，我们来定义一个简单的计算图。
#  1）导入数据。

# %%
import tensorflow as tf
import datetime, os

fashion_mnist = tf.keras.datasets.fashion_mnist

(x_train, y_train),(x_test, y_test) = fashion_mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %% [markdown]
# 2）构建模型。

# %%
def create_model():
  return tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
  ])

# %% [markdown]
# 3）训练模型

# %%
def train_model():

  model = create_model()
  model.compile(optimizer='adam',
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])

  logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
  tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

  model.fit(x=x_train, 
            y=y_train, 
            epochs=5, 
            validation_data=(x_test, y_test), 
            callbacks=[tensorboard_callback])

train_model()
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.6216 - accuracy: 0.7814 - val_loss: 0.4126 - val_accuracy: 0.8564
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3873 - accuracy: 0.8581 - val_loss: 0.3982 - val_accuracy: 0.8518
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3534 - accuracy: 0.8710 - val_loss: 0.3634 - val_accuracy: 0.8700
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3292 - accuracy: 0.8798 - val_loss: 0.3641 - val_accuracy: 0.8656
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3125 - accuracy: 0.8843 - val_loss: 0.3546 - val_accuracy: 0.8753

# %% [markdown]
# 在Windows的命令行启动Tensorboard 服务，指定日志读写路径，如果是linux环境，请根据实际情况，修改logdir的值。
# tensorboard --logdir=“C:\\Users\\wumg\\jupyter-ipynb\\tensorflow2-book\\char-05\\logs”

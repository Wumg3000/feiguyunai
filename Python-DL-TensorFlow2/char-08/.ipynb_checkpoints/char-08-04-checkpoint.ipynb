# %% [markdown]
# https://blog.csdn.net/keeppractice/article/details/105168161?spm=1001.2101.3001.6650.14&utm_medium=distribute.pc_relevant.none-task-blog-2%7Edefault%7ECTRLIST%7Edefault-15.no_search_link&depth_1-utm_source=distribute.pc_relevant.none-task-blog-2%7Edefault%7ECTRLIST%7Edefault-15.no_search_link

# %% [markdown]
# CIFAR10 DenseNet

# %% [markdown]
# ## 1.导入模块

# %%
import os
import math
import numpy as np
import pickle as p
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 2.定义加载函数

# %%
def load_CIFAR_data(data_dir):
    """导入CIFAR数据集"""
 
    images_train=[]
    labels_train=[]
    for i in range(5):
        f=os.path.join(data_dir,'data_batch_%d' % (i+1))
        print('loading ',f)
        # 调用 load_CIFAR_batch( )获得批量的图像及其对应的标签
        image_batch,label_batch=load_CIFAR_batch(f)
        images_train.append(image_batch)
        labels_train.append(label_batch)
        Xtrain=np.concatenate(images_train)
        Ytrain=np.concatenate(labels_train)
        del image_batch ,label_batch
    
    Xtest,Ytest=load_CIFAR_batch(os.path.join(data_dir,'test_batch'))
    print('finished loadding CIFAR-10 data')
    
    # 返回训练集的图像和标签，测试集的图像和标签
    return (Xtrain,Ytrain),(Xtest,Ytest)

# %% [markdown]
# ## 3.定义批量加载函数

# %%
def load_CIFAR_batch(filename):
    """ 批量加载数据集 """  
    with open(filename, 'rb')as f:
        data_dict = p.load(f, encoding='bytes')
        images= data_dict[b'data']
        labels = data_dict[b'labels']
                
        # 把原始数据结构调整为: BCWH
        images = images.reshape(10000, 3, 32, 32)
        # tensorflow处理图像数据的结构：BWHC
        # 把通道数据C移动到最后一个维度
        images = images.transpose (0,2,3,1)
     
        labels = np.array(labels)
        
        return images, labels

# %% [markdown]
# ## 4.运行加载函数

# %%
data_dir = r'..\data\cifar-10-batches-py'
(x_train,y_train),(x_test,y_test) = load_CIFAR_data(data_dir)
# Out:
# loading  ..\data\cifar-10-batches-py\data_batch_1
# loading  ..\data\cifar-10-batches-py\data_batch_2
# loading  ..\data\cifar-10-batches-py\data_batch_3
# loading  ..\data\cifar-10-batches-py\data_batch_4
# loading  ..\data\cifar-10-batches-py\data_batch_5
# finished loadding CIFAR-10 data

# %% [markdown]
# ## 5.可视化加载数据

# %%
label_dict = {0:"airplane", 1:"automobile", 2:"bird", 3:"cat", 4:"deer",
              5:"dog", 6:"frog", 7:"horse", 8:"ship", 9:"truck"}


def plot_images_labels(images, labels, num):
    total = len(images)
    fig = plt.gcf()
    fig.set_size_inches(15, math.ceil(num / 10) * 7)
    for i in range(0, num):
        choose_n = np.random.randint(0, total)
        
        ax = plt.subplot(math.ceil(num / 5), 5, 1 + i)
        ax.imshow(images[choose_n], cmap='binary')
        title = label_dict[labels[choose_n]]
        ax.set_title(title, fontsize=10)        
    plt.show()
    
plot_images_labels(x_train, y_train, 10)

# %% [markdown]
# ## 6.对数据进行预处理

# %%
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

train_num = len(x_train)
num_classes = 10

learning_rate = 0.0002
batch_size = 64
training_steps = 20000
display_step = 1000

conv1_filters = 32
conv2_filters = 64
fc1_units = 256


random_normal = tf.initializers.RandomNormal()
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_data = tf.data.Dataset.from_tensor_slices((x_train, y_train))
#test_data = tf.data.Dataset.from_tensor_slices((x_test, y_test))
#train_data = train_data.shuffle(5000).repeat(training_steps).batch(batch_size).prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### 数据增强

# %%
def convert(image, label):
    image = tf.image.convert_image_dtype(image, tf.float32)
    return image, label
 
def augment(image, label):
    image, label = convert(image, label)
    #image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize_with_crop_or_pad(image, 34,34) # 四周各加3像素
    image = tf.image.random_crop(image, size=[32,32,3]) # 随机裁剪成28*28大小
    image = tf.image.random_brightness(image, max_delta=0.5) # 随机增加亮度
    return image, label
 
batch_size = 64

augmented_train_batches = (train_data
                          #.take(num_examples)
                          .cache()
                         # .repeat()
                          .shuffle(5000)
                          .map(augment, num_parallel_calls=tf.data.experimental.AUTOTUNE)
                          .batch(batch_size)
                          .prefetch(tf.data.experimental.AUTOTUNE))
 
 
#validation_batches = (test_dataset 
#                     .map(convert, num_parallel_calls=tf.data.experimental.AUTOTUNE)
#                     .batch(2*batch_size))

# %% [markdown]
# ## 6.定义网络层

# %%
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.layers as layers

import time as time
import numpy as np
import tensorflow.keras.preprocessing.image as image
import matplotlib.pyplot as plt
import os

# %%
def dense_block(x, blocks, name, growth_rate = 32):
    for i in range(blocks):
        x = conv_block(x, growth_rate, name=name + '_block' + str(i + 1))
    return x

def transition_block(x, reduction, name):
    x = layers.BatchNormalization(axis=3, epsilon=1.001e-5,name=name + '_bn')(x)
    x = layers.Activation('relu', name=name + '_relu')(x)
    filter = x.shape[3]
    x = layers.Conv2D(int(filter*reduction), 1,use_bias=False,name=name + '_conv')(x)
    x = layers.AveragePooling2D(2, strides=2, name=name + '_pool')(x)
    return x

def conv_block(x, growth_rate, name):
    x1 = layers.BatchNormalization(axis=3, epsilon=1.001e-5)(x)
    x1 = layers.Activation('relu')(x1)
    x1 = layers.Conv2D(2 * growth_rate, 1,use_bias=False, name=name + '_1_conv')(x1)
    x1 = layers.BatchNormalization(axis=3, epsilon=1.001e-5)(x1)
    x1 = layers.Activation('relu', name=name + '_1_relu')(x1)
    x1 = layers.Conv2D(growth_rate, 3 ,padding='same',use_bias=False, name=name + '_2_conv')(x1)
    x = layers.Concatenate( name=name + '_concat')([x, x1])
    return x

# %%
def my_densenet():
    inputs = keras.Input(shape=(32, 32, 3), name='img')
    x = layers.Conv2D(filters=16, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu')(inputs)
    x = layers.BatchNormalization()(x)
    blocks = [4,8,16]
    x = dense_block(x, blocks[0], name='conv1',growth_rate =32)
    x = transition_block(x, 0.5, name='pool1')
    x = dense_block(x, blocks[1], name='conv2',growth_rate =32)
    x = transition_block(x, 0.5, name='pool2')
    x = dense_block(x, blocks[2], name='conv3',growth_rate =32)
    x = transition_block(x, 0.5, name='pool3')
    x = layers.BatchNormalization(axis=3, epsilon=1.001e-5, name='bn')(x)
    x = layers.Activation('relu', name='relu')(x)

    x = layers.GlobalAveragePooling2D(name='avg_pool')(x)
    x = layers.Dense(10, activation='softmax', name='fc1000')(x)

    model = keras.Model(inputs, x, name='densenet121')
    return model
def my_model():
    denseNet = my_densenet()

    denseNet.compile(optimizer=keras.optimizers.Adam(),
                 loss=keras.losses.SparseCategoricalCrossentropy(),
                 metrics=[keras.metrics.SparseCategoricalAccuracy()])
    denseNet.summary()
    return denseNet

# %%
current_max_loss = 9999

weight_file='./weights/model.h5'

# %%
def train_my_model(deep_model):
    #(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

    train_datagen = image.ImageDataGenerator(
        rescale=1 / 255,
        rotation_range=40,  # 角度值，0-180.表示图像随机旋转的角度范围
        width_shift_range=0.2,  # 平移比例，下同
        height_shift_range=0.2,
        shear_range=0.2,  # 随机错切变换角度
        zoom_range=0.2,  # 随即缩放比例
        horizontal_flip=True,  # 随机将一半图像水平翻转
        fill_mode='nearest'  # 填充新创建像素的方法
    )

    test_datagen = image.ImageDataGenerator(rescale=1 / 255)

    validation_datagen = image.ImageDataGenerator(rescale=1 / 255)

    train_generator = train_datagen.flow(x_train[:45000], y_train[:45000], batch_size=128)
    # train_generator = train_datagen.flow(x_train, y_train, batch_size=128)
    validation_generator = validation_datagen.flow(x_train[45000:], y_train[45000:], batch_size=128)

    test_generator = test_datagen.flow(x_test, y_test, batch_size=128)

    begin_time = time.time()

    if os.path.isfile(weight_file):
        print('load weight')
        deep_model.load_weights(weight_file)


    def save_weight(epoch, logs):
        global current_max_loss
        if(logs['val_loss'] is not None and  logs['val_loss']< current_max_loss):
            current_max_loss = logs['val_loss']
            print('save_weight', epoch, current_max_loss)
            deep_model.save_weights(weight_file)

    batch_print_callback = keras.callbacks.LambdaCallback(
        on_epoch_end=save_weight
    )
    callbacks = [
        tf.keras.callbacks.EarlyStopping(patience=4, monitor='loss'),
        batch_print_callback,
        # keras.callbacks.ModelCheckpoint('./weights/model.h5', save_best_only=True),
        tf.keras.callbacks.TensorBoard(log_dir='logs')
    ]

    print(train_generator[0][0].shape)
    #######修改
    history = deep_model.fit(train_generator, steps_per_epoch=351, epochs=200, callbacks=callbacks,
                                       validation_data=validation_generator, validation_steps=39, initial_epoch = 0)
    
    if (history.history['val_loss'] is not None and history.history['val_loss'] < current_max_loss):
        current_max_loss = history['val_loss']
        print('save_weight', current_max_loss)
        deep_model.save_weights(weight_file)
    #######修改
    result = deep_model.evaluate(test_generator, verbose=2)

    print(result)
    print('time', time.time() - begin_time)

    def show_result(history):
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.plot(history.history['sparse_categorical_accuracy'])
        plt.plot(history.history['val_sparse_categorical_accuracy'])
        plt.legend(['loss', 'val_loss', 'sparse_categorical_accuracy', 'val_sparse_categorical_accuracy'],
                   loc='upper left')
        plt.show()
        print(history)

    show_result(history)

# %%
def test_module(deep_model):
    #(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

    test_datagen = image.ImageDataGenerator(rescale=1 / 255)


    test_generator = test_datagen.flow(x_test, y_test, batch_size=128)

    begin_time = time.time()

    if os.path.isfile(weight_file):
        print('load weight')
        deep_model.load_weights(weight_file)

    result = deep_model.evaluate(test_generator, verbose=2)

    print(result)
    print('time', time.time() - begin_time)

# %%
def predict_module(deep_model):
    #x_train, y_train, x_test, y_test = image_augment.get_all_train_data(False)
    
    if os.path.isfile(weight_file):
        print('load weight')
        deep_model.load_weights(weight_file)

    print(y_test[0:20])
    for i in range(20):
        img = x_test[i][np.newaxis, :]/255

        y_ = deep_model.predict(img)
        v  = np.argmax(y_)
        print(v, y_test[i])

# %% [markdown]
# ### 训练模型

# %%
deep_model = my_model()
# Out:
# Model: "densenet121"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 16)   448         img[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 32, 32, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 32, 32, 16)   64          batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 32, 32, 16)   0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv1_block1_1_conv (Conv2D)    (None, 32, 32, 64)   1024        activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 32, 32, 64)   256         conv1_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_block1_1_relu (Activation (None, 32, 32, 64)   0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv1_block1_2_conv (Conv2D)    (None, 32, 32, 32)   18432       conv1_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv1_block1_concat (Concatenat (None, 32, 32, 48)   0           batch_normalization_57[0][0]
#                                                                  conv1_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 32, 32, 48)   192         conv1_block1_concat[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 32, 32, 48)   0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv1_block2_1_conv (Conv2D)    (None, 32, 32, 64)   3072        activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 32, 32, 64)   256         conv1_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_block2_1_relu (Activation (None, 32, 32, 64)   0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv1_block2_2_conv (Conv2D)    (None, 32, 32, 32)   18432       conv1_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv1_block2_concat (Concatenat (None, 32, 32, 80)   0           conv1_block1_concat[0][0]
#                                                                  conv1_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 32, 32, 80)   320         conv1_block2_concat[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 32, 32, 80)   0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv1_block3_1_conv (Conv2D)    (None, 32, 32, 64)   5120        activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 32, 32, 64)   256         conv1_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_block3_1_relu (Activation (None, 32, 32, 64)   0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv1_block3_2_conv (Conv2D)    (None, 32, 32, 32)   18432       conv1_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv1_block3_concat (Concatenat (None, 32, 32, 112)  0           conv1_block2_concat[0][0]
#                                                                  conv1_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 32, 32, 112)  448         conv1_block3_concat[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 32, 32, 112)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv1_block4_1_conv (Conv2D)    (None, 32, 32, 64)   7168        activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 32, 32, 64)   256         conv1_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_block4_1_relu (Activation (None, 32, 32, 64)   0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv1_block4_2_conv (Conv2D)    (None, 32, 32, 32)   18432       conv1_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv1_block4_concat (Concatenat (None, 32, 32, 144)  0           conv1_block3_concat[0][0]
#                                                                  conv1_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# pool1_bn (BatchNormalization)   (None, 32, 32, 144)  576         conv1_block4_concat[0][0]
# __________________________________________________________________________________________________
# pool1_relu (Activation)         (None, 32, 32, 144)  0           pool1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_conv (Conv2D)             (None, 32, 32, 72)   10368       pool1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (AveragePooling2D)   (None, 16, 16, 72)   0           pool1_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 16, 16, 72)   288         pool1_pool[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 16, 16, 72)   0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 16, 16, 64)   4608        activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 16, 16, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 16, 16, 64)   0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 16, 16, 32)   18432       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_concat (Concatenat (None, 16, 16, 104)  0           pool1_pool[0][0]
#                                                                  conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 16, 16, 104)  416         conv2_block1_concat[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 16, 16, 104)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 16, 16, 64)   6656        activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 16, 16, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 16, 16, 64)   0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 16, 16, 32)   18432       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_concat (Concatenat (None, 16, 16, 136)  0           conv2_block1_concat[0][0]
#                                                                  conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 16, 16, 136)  544         conv2_block2_concat[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 16, 16, 136)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 16, 16, 64)   8704        activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 16, 16, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 16, 16, 64)   0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 16, 16, 32)   18432       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_concat (Concatenat (None, 16, 16, 168)  0           conv2_block2_concat[0][0]
#                                                                  conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 16, 16, 168)  672         conv2_block3_concat[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 16, 16, 168)  0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_conv (Conv2D)    (None, 16, 16, 64)   10752       activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 16, 16, 64)   256         conv2_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_relu (Activation (None, 16, 16, 64)   0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv2_block4_2_conv (Conv2D)    (None, 16, 16, 32)   18432       conv2_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_concat (Concatenat (None, 16, 16, 200)  0           conv2_block3_concat[0][0]
#                                                                  conv2_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 16, 16, 200)  800         conv2_block4_concat[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 16, 16, 200)  0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_conv (Conv2D)    (None, 16, 16, 64)   12800       activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 16, 16, 64)   256         conv2_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_relu (Activation (None, 16, 16, 64)   0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv2_block5_2_conv (Conv2D)    (None, 16, 16, 32)   18432       conv2_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_concat (Concatenat (None, 16, 16, 232)  0           conv2_block4_concat[0][0]
#                                                                  conv2_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 16, 16, 232)  928         conv2_block5_concat[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 16, 16, 232)  0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_conv (Conv2D)    (None, 16, 16, 64)   14848       activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 16, 16, 64)   256         conv2_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_relu (Activation (None, 16, 16, 64)   0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# conv2_block6_2_conv (Conv2D)    (None, 16, 16, 32)   18432       conv2_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_concat (Concatenat (None, 16, 16, 264)  0           conv2_block5_concat[0][0]
#                                                                  conv2_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 16, 16, 264)  1056        conv2_block6_concat[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 16, 16, 264)  0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv2_block7_1_conv (Conv2D)    (None, 16, 16, 64)   16896       activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 16, 16, 64)   256         conv2_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block7_1_relu (Activation (None, 16, 16, 64)   0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# conv2_block7_2_conv (Conv2D)    (None, 16, 16, 32)   18432       conv2_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block7_concat (Concatenat (None, 16, 16, 296)  0           conv2_block6_concat[0][0]
#                                                                  conv2_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 16, 16, 296)  1184        conv2_block7_concat[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 16, 16, 296)  0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2_block8_1_conv (Conv2D)    (None, 16, 16, 64)   18944       activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 16, 16, 64)   256         conv2_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block8_1_relu (Activation (None, 16, 16, 64)   0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2_block8_2_conv (Conv2D)    (None, 16, 16, 32)   18432       conv2_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block8_concat (Concatenat (None, 16, 16, 328)  0           conv2_block7_concat[0][0]
#                                                                  conv2_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# pool2_bn (BatchNormalization)   (None, 16, 16, 328)  1312        conv2_block8_concat[0][0]
# __________________________________________________________________________________________________
# pool2_relu (Activation)         (None, 16, 16, 328)  0           pool2_bn[0][0]
# __________________________________________________________________________________________________
# pool2_conv (Conv2D)             (None, 16, 16, 164)  53792       pool2_relu[0][0]
# __________________________________________________________________________________________________
# pool2_pool (AveragePooling2D)   (None, 8, 8, 164)    0           pool2_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 8, 8, 164)    656         pool2_pool[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 8, 8, 164)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 8, 8, 64)     10496       activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 8, 8, 64)     256         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 8, 8, 64)     0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 8, 8, 32)     18432       conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_concat (Concatenat (None, 8, 8, 196)    0           pool2_pool[0][0]
#                                                                  conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 8, 8, 196)    784         conv3_block1_concat[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 8, 8, 196)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 8, 8, 64)     12544       activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 8, 8, 64)     256         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 8, 8, 64)     0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 8, 8, 32)     18432       conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_concat (Concatenat (None, 8, 8, 228)    0           conv3_block1_concat[0][0]
#                                                                  conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 8, 8, 228)    912         conv3_block2_concat[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 8, 8, 228)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 8, 8, 64)     14592       activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 8, 8, 64)     256         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 8, 8, 64)     0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 8, 8, 32)     18432       conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_concat (Concatenat (None, 8, 8, 260)    0           conv3_block2_concat[0][0]
#                                                                  conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 8, 8, 260)    1040        conv3_block3_concat[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 8, 8, 260)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 8, 8, 64)     16640       activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 8, 8, 64)     256         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 8, 8, 64)     0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 8, 8, 32)     18432       conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_concat (Concatenat (None, 8, 8, 292)    0           conv3_block3_concat[0][0]
#                                                                  conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 8, 8, 292)    1168        conv3_block4_concat[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 8, 8, 292)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 8, 8, 64)     18688       activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 8, 8, 64)     256         conv3_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (Activation (None, 8, 8, 64)     0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 8, 8, 32)     18432       conv3_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_concat (Concatenat (None, 8, 8, 324)    0           conv3_block4_concat[0][0]
#                                                                  conv3_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 8, 8, 324)    1296        conv3_block5_concat[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 8, 8, 324)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 8, 8, 64)     20736       activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 8, 8, 64)     256         conv3_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (Activation (None, 8, 8, 64)     0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 8, 8, 32)     18432       conv3_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_concat (Concatenat (None, 8, 8, 356)    0           conv3_block5_concat[0][0]
#                                                                  conv3_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 8, 8, 356)    1424        conv3_block6_concat[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 8, 8, 356)    0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_conv (Conv2D)    (None, 8, 8, 64)     22784       activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 8, 8, 64)     256         conv3_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_relu (Activation (None, 8, 8, 64)     0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_conv (Conv2D)    (None, 8, 8, 32)     18432       conv3_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_concat (Concatenat (None, 8, 8, 388)    0           conv3_block6_concat[0][0]
#                                                                  conv3_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 8, 8, 388)    1552        conv3_block7_concat[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 8, 8, 388)    0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_conv (Conv2D)    (None, 8, 8, 64)     24832       activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 8, 8, 64)     256         conv3_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_relu (Activation (None, 8, 8, 64)     0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_conv (Conv2D)    (None, 8, 8, 32)     18432       conv3_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_concat (Concatenat (None, 8, 8, 420)    0           conv3_block7_concat[0][0]
#                                                                  conv3_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 8, 8, 420)    1680        conv3_block8_concat[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 8, 8, 420)    0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_conv (Conv2D)    (None, 8, 8, 64)     26880       activation_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 8, 8, 64)     256         conv3_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_relu (Activation (None, 8, 8, 64)     0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# conv3_block9_2_conv (Conv2D)    (None, 8, 8, 32)     18432       conv3_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_concat (Concatenat (None, 8, 8, 452)    0           conv3_block8_concat[0][0]
#                                                                  conv3_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 8, 8, 452)    1808        conv3_block9_concat[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 8, 8, 452)    0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_conv (Conv2D)   (None, 8, 8, 64)     28928       activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 8, 8, 64)     256         conv3_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_relu (Activatio (None, 8, 8, 64)     0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# conv3_block10_2_conv (Conv2D)   (None, 8, 8, 32)     18432       conv3_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_concat (Concatena (None, 8, 8, 484)    0           conv3_block9_concat[0][0]
#                                                                  conv3_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 8, 8, 484)    1936        conv3_block10_concat[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 8, 8, 484)    0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_conv (Conv2D)   (None, 8, 8, 64)     30976       activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 8, 8, 64)     256         conv3_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_relu (Activatio (None, 8, 8, 64)     0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# conv3_block11_2_conv (Conv2D)   (None, 8, 8, 32)     18432       conv3_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_concat (Concatena (None, 8, 8, 516)    0           conv3_block10_concat[0][0]
#                                                                  conv3_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 8, 8, 516)    2064        conv3_block11_concat[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 8, 8, 516)    0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_conv (Conv2D)   (None, 8, 8, 64)     33024       activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 8, 8, 64)     256         conv3_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_relu (Activatio (None, 8, 8, 64)     0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# conv3_block12_2_conv (Conv2D)   (None, 8, 8, 32)     18432       conv3_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_concat (Concatena (None, 8, 8, 548)    0           conv3_block11_concat[0][0]
#                                                                  conv3_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 8, 8, 548)    2192        conv3_block12_concat[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 8, 8, 548)    0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# conv3_block13_1_conv (Conv2D)   (None, 8, 8, 64)     35072       activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 8, 8, 64)     256         conv3_block13_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block13_1_relu (Activatio (None, 8, 8, 64)     0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# conv3_block13_2_conv (Conv2D)   (None, 8, 8, 32)     18432       conv3_block13_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block13_concat (Concatena (None, 8, 8, 580)    0           conv3_block12_concat[0][0]
#                                                                  conv3_block13_2_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 8, 8, 580)    2320        conv3_block13_concat[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 8, 8, 580)    0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# conv3_block14_1_conv (Conv2D)   (None, 8, 8, 64)     37120       activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 8, 8, 64)     256         conv3_block14_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block14_1_relu (Activatio (None, 8, 8, 64)     0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# conv3_block14_2_conv (Conv2D)   (None, 8, 8, 32)     18432       conv3_block14_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block14_concat (Concatena (None, 8, 8, 612)    0           conv3_block13_concat[0][0]
#                                                                  conv3_block14_2_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 8, 8, 612)    2448        conv3_block14_concat[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 8, 8, 612)    0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# conv3_block15_1_conv (Conv2D)   (None, 8, 8, 64)     39168       activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 8, 8, 64)     256         conv3_block15_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block15_1_relu (Activatio (None, 8, 8, 64)     0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# conv3_block15_2_conv (Conv2D)   (None, 8, 8, 32)     18432       conv3_block15_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block15_concat (Concatena (None, 8, 8, 644)    0           conv3_block14_concat[0][0]
#                                                                  conv3_block15_2_conv[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 8, 8, 644)    2576        conv3_block15_concat[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 8, 8, 644)    0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# conv3_block16_1_conv (Conv2D)   (None, 8, 8, 64)     41216       activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 8, 8, 64)     256         conv3_block16_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block16_1_relu (Activatio (None, 8, 8, 64)     0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# conv3_block16_2_conv (Conv2D)   (None, 8, 8, 32)     18432       conv3_block16_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block16_concat (Concatena (None, 8, 8, 676)    0           conv3_block15_concat[0][0]
#                                                                  conv3_block16_2_conv[0][0]
# __________________________________________________________________________________________________
# pool3_bn (BatchNormalization)   (None, 8, 8, 676)    2704        conv3_block16_concat[0][0]
# __________________________________________________________________________________________________
# pool3_relu (Activation)         (None, 8, 8, 676)    0           pool3_bn[0][0]
# __________________________________________________________________________________________________
# pool3_conv (Conv2D)             (None, 8, 8, 338)    228488      pool3_relu[0][0]
# __________________________________________________________________________________________________
# pool3_pool (AveragePooling2D)   (None, 4, 4, 338)    0           pool3_conv[0][0]
# __________________________________________________________________________________________________
# bn (BatchNormalization)         (None, 4, 4, 338)    1352        pool3_pool[0][0]
# __________________________________________________________________________________________________
# relu (Activation)               (None, 4, 4, 338)    0           bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 338)          0           relu[0][0]
# __________________________________________________________________________________________________
# fc1000 (Dense)                  (None, 10)           3390        avg_pool[0][0]
# ==================================================================================================
# Total params: 1,382,814
# Trainable params: 1,359,842
# Non-trainable params: 22,972
# __________________________________________________________________________________________________

# %%
train_my_model(deep_model)
# Out:
# (128, 32, 32, 3)
# Epoch 1/200
# 351/351 [==============================] - 60s 159ms/step - loss: 1.7815 - sparse_categorical_accuracy: 0.3458 - val_loss: 1.6882 - val_sparse_categorical_accuracy: 0.3712
# save_weight 0 1.6882038116455078
# Epoch 2/200
# 351/351 [==============================] - 48s 137ms/step - loss: 1.2981 - sparse_categorical_accuracy: 0.5370 - val_loss: 2.2069 - val_sparse_categorical_accuracy: 0.4235
# Epoch 3/200
# 351/351 [==============================] - 49s 138ms/step - loss: 1.0911 - sparse_categorical_accuracy: 0.6123 - val_loss: 2.8000 - val_sparse_categorical_accuracy: 0.4157
# Epoch 4/200
# 351/351 [==============================] - 48s 137ms/step - loss: 0.9335 - sparse_categorical_accuracy: 0.6722 - val_loss: 1.1467 - val_sparse_categorical_accuracy: 0.6414
# save_weight 3 1.1467441320419312
# Epoch 5/200
# 351/351 [==============================] - 48s 138ms/step - loss: 0.8428 - sparse_categorical_accuracy: 0.7045 - val_loss: 1.0393 - val_sparse_categorical_accuracy: 0.6797
# save_weight 4 1.0393210649490356
# Epoch 6/200
# 351/351 [==============================] - 48s 138ms/step - loss: 0.7742 - sparse_categorical_accuracy: 0.7290 - val_loss: 1.0735 - val_sparse_categorical_accuracy: 0.6823
# Epoch 7/200
# 351/351 [==============================] - 48s 138ms/step - loss: 0.7094 - sparse_categorical_accuracy: 0.7544 - val_loss: 1.3673 - val_sparse_categorical_accuracy: 0.5980
# Epoch 8/200
# 351/351 [==============================] - 48s 138ms/step - loss: 0.6807 - sparse_categorical_accuracy: 0.7632 - val_loss: 0.7774 - val_sparse_categorical_accuracy: 0.7442
# save_weight 7 0.777416467666626
# Epoch 9/200
# 351/351 [==============================] - 49s 138ms/step - loss: 0.6184 - sparse_categorical_accuracy: 0.7849 - val_loss: 1.0191 - val_sparse_categorical_accuracy: 0.7013
# Epoch 10/200
# 351/351 [==============================] - 49s 138ms/step - loss: 0.5907 - sparse_categorical_accuracy: 0.7958 - val_loss: 0.8149 - val_sparse_categorical_accuracy: 0.7340
# Epoch 11/200
# 351/351 [==============================] - 48s 138ms/step - loss: 0.5551 - sparse_categorical_accuracy: 0.8124 - val_loss: 0.8371 - val_sparse_categorical_accuracy: 0.7518
# Epoch 12/200
# 351/351 [==============================] - 49s 139ms/step - loss: 0.5317 - sparse_categorical_accuracy: 0.8149 - val_loss: 0.7558 - val_sparse_categorical_accuracy: 0.7738
# save_weight 11 0.75577312707901
# Epoch 13/200
# 351/351 [==============================] - 48s 138ms/step - loss: 0.5180 - sparse_categorical_accuracy: 0.8186 - val_loss: 0.8962 - val_sparse_categorical_accuracy: 0.7526
# Epoch 14/200
# 351/351 [==============================] - 48s 138ms/step - loss: 0.4924 - sparse_categorical_accuracy: 0.8281 - val_loss: 0.6071 - val_sparse_categorical_accuracy: 0.7943
# save_weight 13 0.6071369647979736
# Epoch 15/200
# 351/351 [==============================] - 48s 138ms/step - loss: 0.4691 - sparse_categorical_accuracy: 0.8366 - val_loss: 0.6627 - val_sparse_categorical_accuracy: 0.7981
# Epoch 16/200
# 351/351 [==============================] - 49s 138ms/step - loss: 0.4440 - sparse_categorical_accuracy: 0.8461 - val_loss: 0.8581 - val_sparse_categorical_accuracy: 0.7610
# Epoch 17/200
# 351/351 [==============================] - 48s 138ms/step - loss: 0.4337 - sparse_categorical_accuracy: 0.8493 - val_loss: 0.5857 - val_sparse_categorical_accuracy: 0.8101
# save_weight 16 0.5857313871383667
# Epoch 18/200
# 351/351 [==============================] - 48s 138ms/step - loss: 0.4206 - sparse_categorical_accuracy: 0.8558 - val_loss: 0.5303 - val_sparse_categorical_accuracy: 0.8267
# save_weight 17 0.5302899479866028
# Epoch 19/200
# 351/351 [==============================] - 48s 138ms/step - loss: 0.4054 - sparse_categorical_accuracy: 0.8561 - val_loss: 0.4747 - val_sparse_categorical_accuracy: 0.8500
# save_weight 18 0.47467172145843506
# Epoch 20/200
# 351/351 [==============================] - 48s 138ms/step - loss: 0.3916 - sparse_categorical_accuracy: 0.8647 - val_loss: 0.6644 - val_sparse_categorical_accuracy: 0.8037
# Epoch 21/200
# 351/351 [==============================] - 48s 138ms/step - loss: 0.3817 - sparse_categorical_accuracy: 0.8672 - val_loss: 0.5828 - val_sparse_categorical_accuracy: 0.8253
# Epoch 22/200
# 351/351 [==============================] - 48s 138ms/step - loss: 0.3680 - sparse_categorical_accuracy: 0.8720 - val_loss: 0.5760 - val_sparse_categorical_accuracy: 0.8261
# Epoch 23/200
# 351/351 [==============================] - 48s 138ms/step - loss: 0.3623 - sparse_categorical_accuracy: 0.8748 - val_loss: 0.6641 - val_sparse_categorical_accuracy: 0.8111
# Epoch 24/200
# 351/351 [==============================] - 49s 138ms/step - loss: 0.3487 - sparse_categorical_accuracy: 0.8787 - val_loss: 0.5329 - val_sparse_categorical_accuracy: 0.8395
# Epoch 25/200
# 351/351 [==============================] - 49s 139ms/step - loss: 0.3440 - sparse_categorical_accuracy: 0.8801 - val_loss: 0.7719 - val_sparse_categorical_accuracy: 0.7768
# Epoch 26/200
# 351/351 [==============================] - ETA: 0s - loss: 0.3268 - sparse_categorical_accuracy: 0.8846
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-f1b58123bb2e> in <module>
# ----> 1 train_my_model(deep_model)
#
# <ipython-input-16-6050d910f25c> in train_my_model(deep_model)
#      50     #######修改
#      51     history = deep_model.fit(train_generator, steps_per_epoch=351, epochs=200, callbacks=callbacks,
# ---> 52                                        validation_data=validation_generator, validation_steps=39, initial_epoch = 0)
#      53
#      54     if (history.history['val_loss'] is not None and history.history['val_loss'] < current_max_loss):
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1139               workers=workers,
#    1140               use_multiprocessing=use_multiprocessing,
# -> 1141               return_dict=True)
#    1142           val_logs = {'val_' + name: val for name, val in val_logs.items()}
#    1143           epoch_logs.update(val_logs)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict)
#    1387             with trace.Trace('test', step_num=step, _r=1):
#    1388               callbacks.on_test_batch_begin(step)
# -> 1389               tmp_logs = self.test_function(iterator)
#    1390               if data_handler.should_sync:
#    1391                 context.async_wait()
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     860       # In this case we have not created variables on the first call. So we can
#     861       # run the first trace but we should fail if variables are created.
# --> 862       results = self._stateful_fn(*args, **kwds)
#     863       if self._created_variables:
#     864         raise ValueError("Creating variables on a non-first call to a function"
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

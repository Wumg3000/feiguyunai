# %%
import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from tqdm import tqdm
import matplotlib.pylab as plt
# %matplotlib inline

# %% [markdown]
# ## 设置一些超参数

# %%
# Hyperparameters etc.
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
LEARNING_RATE = 5e-5  # could also use two lrs, one for gen and one for disc
BATCH_SIZE = 64
IMAGE_SIZE = 64
CHANNELS_IMG = 3
NOISE_DIM = 100
NUM_EPOCHS = 10
FEATURES_DISC = 64
FEATURES_GEN = 64
CRITIC_ITERATIONS = 5
WEIGHT_CLIP = 0.02

# %% [markdown]
# ## 数据预处理

# %%
transforms = transforms.Compose([
    transforms.Resize([64,64]),
    transforms.ToTensor(),
    transforms.Normalize([0.5 for i in range(CHANNELS_IMG)], [0.5 for i in range(CHANNELS_IMG)])
])

# %% [markdown]
# ## 获取数据集

# %%
IMAGE_PATH = '../data/celeba/'

# %%
dataset = datasets.ImageFolder(IMAGE_PATH, transform = transforms)

# %%
def split_indices(n, val_per, seed = 0):
    n_val = int(n * val_per)
    np.random.seed(seed)
    idx = np.random.permutation(n)
    return idx[n_val : ], idx[: n_val]

# %%
val_per = 0.4
rand_seed = 42

train_indices, val_indices = split_indices(len(dataset), val_per, rand_seed)

print(len(train_indices), len(val_indices))
# Out:
# 121562 81040

# %%
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data.dataloader import DataLoader

# %%
# training data loader
train_sampler = SubsetRandomSampler(train_indices)
loader = DataLoader(dataset, BATCH_SIZE, sampler = train_sampler)

# %%
len(dataset), len(loader)
# Out:
# (202602, 1900)

# %% [markdown]
# ## 构建判断模型

# %%
class Discriminator(nn.Module):
    
    def __init__(self, channels_img, features_d):
        super(Discriminator, self).__init__()
        
        self.disc = nn.Sequential(
            #size = 3*64*64
            nn.Conv2d(channels_img, features_d, kernel_size = 4, stride = 2, padding = 1), # Size : 32*32
            nn.LeakyReLU(0.2),
            
            nn.Conv2d(features_d, features_d*2, kernel_size = 4, stride = 2, padding = 1), # size = 16*16
            nn.BatchNorm2d(features_d*2),
            nn.LeakyReLU(0.2),
            
            nn.Conv2d(features_d*2, features_d*4, kernel_size = 4, stride = 2, padding = 1), # size = 8*8
            nn.BatchNorm2d(features_d*4),
            nn.LeakyReLU(0.2),
            
            nn.Conv2d(features_d*4, features_d*8, kernel_size = 4, stride = 2, padding = 1), # size = 4*4
            nn.BatchNorm2d(features_d*8),
            nn.LeakyReLU(0.2),
            
            nn.Conv2d(features_d*8, 1, kernel_size = 4, stride = 2, padding = 0) #1*1
            
        )
        
        
    def forward(self, x):
        return self.disc(x)

# %% [markdown]
# ## 定义生成网络

# %%
class Generator(nn.Module):
    
    def __init__(self, z_dim, channels_img, features_g):
        super(Generator, self).__init__()
        
        self.net = nn.Sequential(
            nn.ConvTranspose2d(z_dim, features_g*16, kernel_size = 4, stride = 1, padding = 0), # size = 4*4
            nn.BatchNorm2d(features_g*16),
            nn.ReLU(),
            
            nn.ConvTranspose2d(features_g*16, features_g*8, kernel_size = 4, stride = 2, padding = 1), # size = 8*8
            nn.BatchNorm2d(features_g*8),
            nn.ReLU(),
            
            nn.ConvTranspose2d(features_g*8, features_g*4, kernel_size = 4, stride = 2, padding = 1), # size = 16*16
            nn.BatchNorm2d(features_g*4),
            nn.ReLU(),
            
            nn.ConvTranspose2d(features_g*4, features_g*2, kernel_size = 4, stride = 2, padding = 1), # size = 32*32
            nn.BatchNorm2d(features_g*2),
            nn.ReLU(),
            
            nn.ConvTranspose2d(features_g*2, channels_img, kernel_size = 4, stride = 2, padding = 1),
            nn.Tanh()  # [-1, 1]
        )
        
    
    def forward(self, x):
        return self.net(x)

# %% [markdown]
# ## 权重初始化

# %%
def initialize_weights(model):
    # Initializes weights according to the DCGAN paper
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d, nn.BatchNorm2d)):
            nn.init.normal_(m.weight.data, 0.0, 0.02)

# %% [markdown]
# ## 测试模型

# %%
def test():
    N, in_channels, H, W = 8, 3, 64, 64
    noise_dim = 100
    x = torch.randn((N, in_channels, H, W))
    disc = Discriminator(in_channels, 8)
    assert disc(x).shape == (N, 1, 1, 1), "Discriminator test failed"
    gen = Generator(noise_dim, in_channels, 8)
    z = torch.randn((N, noise_dim, 1, 1))
    assert gen(z).shape == (N, in_channels, H, W), "Generator test failed"
    print('Success')

# %%
test()
# Out:
# Success

# %% [markdown]
# ## 初始化模型

# %%
dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)
gen = Generator(z_dim = NOISE_DIM, channels_img = CHANNELS_IMG, features_g = FEATURES_GEN).to(device)
disc = Discriminator(CHANNELS_IMG, FEATURES_DISC).to(device)
initialize_weights(gen)
initialize_weights(disc)

# %%
opt_gen = optim.RMSprop(gen.parameters(), lr = LEARNING_RATE)
opt_disc = optim.RMSprop(disc.parameters(), lr = LEARNING_RATE)

# %%
def reset_grad():
    opt_disc.zero_grad()
    opt_gen.zero_grad()

# %% [markdown]
# ## 定义训练判别模型函数

# %%
def train_discriminator(images):
    # create labels, for real image label is 1, for fake 
    
    # loss for real images
    
    for _ in range(CRITIC_ITERATIONS):
        
        disc_real = disc(images).reshape(-1)
        #d_loss_real = torch.mean(disc_real)
        real_score = disc_real
        
        
        z = torch.randn(BATCH_SIZE, NOISE_DIM, 1, 1).to(device)
        fake_images = gen(z)
        disc_fake = disc(fake_images).reshape(-1)
        #d_loss_fake = torch.mean(disc_fake)
        fake_score = disc_fake
        
        loss_disc = - (torch.mean(disc_real) - torch.mean(disc_fake))
        
        reset_grad()
        
        loss_disc.backward()
        
        opt_disc.step()
        
        for p in disc.parameters():
                p.data.clamp_(-WEIGHT_CLIP, WEIGHT_CLIP)
        
        return loss_disc, real_score, fake_score

# %% [markdown]
# ## 定义训练生成模型函数

# %%
def train_generator():
    # Generate fake images and calculate loss
    z = torch.randn(BATCH_SIZE, NOISE_DIM, 1, 1).to(device)
    fake_images = gen(z)
    labels = torch.ones(BATCH_SIZE, 1).to(device)
    output = disc(fake_images).reshape(-1)
    g_loss = - torch.mean(output)

    # Backprop and optimize
    reset_grad()
    g_loss.backward()
    opt_gen.step()
    return g_loss, fake_images

# %%
import os

sample_dir = 'samples'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %%
def show_img(img, label):
    print('Label: ', label)
    plt.imshow(img.permute(1,2,0), cmap = 'gray')

# %%
def denorm(x):
  out = (x + 1) / 2
  return out.clamp(0, 1)

# %%
from IPython.display import Image
from torchvision.utils import save_image

# Save some real images
for images, _ in loader:
    images = images.reshape(images.size(0), 3, 64, 64)
    save_image(denorm(images), os.path.join(sample_dir, 'real_images.png'), nrow=16)
    break
   
Image(os.path.join(sample_dir, 'real_images.png'))

# %% [markdown]
# ## 保存图像代码

# %%
sample_vectors = torch.randn(BATCH_SIZE, NOISE_DIM, 1, 1).to(device)

def save_fake_images(index):
    fake_images = gen(sample_vectors)
    fake_images = fake_images.reshape(fake_images.size(0), 3, 64, 64)
    fake_fname = 'fake_images-{0:0=4d}.png'.format(index)
    print('Saving', fake_fname)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=16)
    
# Before training
save_fake_images(0)
Image(os.path.join(sample_dir, 'fake_images-0000.png'))
# Out:
# Saving fake_images-0000.png

# %% [markdown]
# ## 训练模型

# %%
# %%time


total_step = len(loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(NUM_EPOCHS):
    for i, (images, _) in enumerate(loader):
        # Load a batch & transform to vectors
        images = images.to(device)
        
        # Train the discriminator and generator
        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()
        
        # Inspect the losses
        if (i+1) % 100 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}' 
                  .format(epoch, NUM_EPOCHS, i+1, total_step, d_loss.item(), g_loss.item(), 
                          real_score.mean().item(), fake_score.mean().item()))
        
    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# Epoch [0/10], Step [100/1900], d_loss: -5.1632, g_loss: 2.3336, D(x): 2.84, D(G(z)): -2.33
# Epoch [0/10], Step [200/1900], d_loss: -5.6401, g_loss: 2.5040, D(x): 3.14, D(G(z)): -2.50
# Epoch [0/10], Step [300/1900], d_loss: -5.7313, g_loss: 2.5809, D(x): 3.21, D(G(z)): -2.52
# Epoch [0/10], Step [400/1900], d_loss: -5.9280, g_loss: 2.6286, D(x): 3.30, D(G(z)): -2.62
# Epoch [0/10], Step [500/1900], d_loss: -5.9537, g_loss: 2.6370, D(x): 3.32, D(G(z)): -2.63
# Epoch [0/10], Step [600/1900], d_loss: -5.9253, g_loss: 2.6369, D(x): 3.30, D(G(z)): -2.62
# Epoch [0/10], Step [700/1900], d_loss: -5.8735, g_loss: 2.6377, D(x): 3.25, D(G(z)): -2.62
# Epoch [0/10], Step [800/1900], d_loss: -5.8908, g_loss: 2.6467, D(x): 3.24, D(G(z)): -2.65
# Epoch [0/10], Step [900/1900], d_loss: -5.9263, g_loss: 2.6535, D(x): 3.27, D(G(z)): -2.66
# Epoch [0/10], Step [1000/1900], d_loss: -5.3278, g_loss: 2.5824, D(x): 3.22, D(G(z)): -2.11
# Epoch [0/10], Step [1100/1900], d_loss: -5.8438, g_loss: 2.6413, D(x): 3.23, D(G(z)): -2.61
# Epoch [0/10], Step [1200/1900], d_loss: -5.7032, g_loss: 2.5707, D(x): 3.11, D(G(z)): -2.59
# Epoch [0/10], Step [1300/1900], d_loss: -4.8864, g_loss: 2.3395, D(x): 2.50, D(G(z)): -2.38
# Epoch [0/10], Step [1400/1900], d_loss: -3.5447, g_loss: 2.2824, D(x): 2.79, D(G(z)): -0.76
# Epoch [0/10], Step [1500/1900], d_loss: -3.2021, g_loss: 1.0570, D(x): 1.30, D(G(z)): -1.90
# Epoch [0/10], Step [1600/1900], d_loss: -2.3532, g_loss: 0.5854, D(x): 0.60, D(G(z)): -1.76
# Epoch [0/10], Step [1700/1900], d_loss: -2.3143, g_loss: 0.7530, D(x): 0.35, D(G(z)): -1.96
# Epoch [0/10], Step [1800/1900], d_loss: -1.4055, g_loss: 1.2884, D(x): 0.62, D(G(z)): -0.79
# Epoch [0/10], Step [1900/1900], d_loss: -1.1534, g_loss: 1.0697, D(x): 0.87, D(G(z)): -0.28
# Saving fake_images-0001.png
# Epoch [1/10], Step [100/1900], d_loss: -1.2714, g_loss: 1.4840, D(x): 1.29, D(G(z)): 0.02
# Epoch [1/10], Step [200/1900], d_loss: -1.3107, g_loss: 1.3177, D(x): 1.33, D(G(z)): 0.02
# Epoch [1/10], Step [300/1900], d_loss: -2.0541, g_loss: 1.7708, D(x): 1.69, D(G(z)): -0.36
# Epoch [1/10], Step [400/1900], d_loss: -1.6132, g_loss: 0.0970, D(x): 0.21, D(G(z)): -1.40
# Epoch [1/10], Step [500/1900], d_loss: -1.8077, g_loss: 1.6963, D(x): 1.89, D(G(z)): 0.08
# Epoch [1/10], Step [600/1900], d_loss: -2.1120, g_loss: 1.4714, D(x): 1.81, D(G(z)): -0.30
# Epoch [1/10], Step [700/1900], d_loss: -1.3935, g_loss: 1.7678, D(x): 2.12, D(G(z)): 0.73
# Epoch [1/10], Step [800/1900], d_loss: -2.2807, g_loss: 0.6048, D(x): 1.08, D(G(z)): -1.21
# Epoch [1/10], Step [900/1900], d_loss: -1.3116, g_loss: 1.2819, D(x): 1.39, D(G(z)): 0.08
# Epoch [1/10], Step [1000/1900], d_loss: -1.8135, g_loss: 1.2125, D(x): 1.14, D(G(z)): -0.67
# Epoch [1/10], Step [1100/1900], d_loss: -2.3110, g_loss: 1.1721, D(x): 1.43, D(G(z)): -0.88
# Epoch [1/10], Step [1200/1900], d_loss: -2.2593, g_loss: 0.6991, D(x): 0.81, D(G(z)): -1.45
# Epoch [1/10], Step [1300/1900], d_loss: -2.5614, g_loss: 0.6287, D(x): 1.02, D(G(z)): -1.54
# Epoch [1/10], Step [1400/1900], d_loss: -1.7904, g_loss: 0.4453, D(x): 0.44, D(G(z)): -1.35
# Epoch [1/10], Step [1500/1900], d_loss: -2.1444, g_loss: 1.3643, D(x): 1.35, D(G(z)): -0.80
# Epoch [1/10], Step [1600/1900], d_loss: -1.9490, g_loss: 0.6688, D(x): 0.51, D(G(z)): -1.44
# Epoch [1/10], Step [1700/1900], d_loss: -1.9532, g_loss: -0.2803, D(x): 0.28, D(G(z)): -1.67
# Epoch [1/10], Step [1800/1900], d_loss: -2.2946, g_loss: -0.0630, D(x): 0.62, D(G(z)): -1.67
# Epoch [1/10], Step [1900/1900], d_loss: -1.6379, g_loss: 0.4192, D(x): 0.28, D(G(z)): -1.35
# Saving fake_images-0002.png
# Epoch [2/10], Step [100/1900], d_loss: -1.3592, g_loss: 0.2058, D(x): -0.50, D(G(z)): -1.86
# Epoch [2/10], Step [200/1900], d_loss: -1.6089, g_loss: 0.4819, D(x): 0.03, D(G(z)): -1.58
# Epoch [2/10], Step [300/1900], d_loss: -2.0594, g_loss: 0.4945, D(x): 0.53, D(G(z)): -1.53
# Epoch [2/10], Step [400/1900], d_loss: -2.0073, g_loss: 1.7405, D(x): 1.93, D(G(z)): -0.07
# Epoch [2/10], Step [500/1900], d_loss: -2.0496, g_loss: 1.7034, D(x): 1.91, D(G(z)): -0.14
# Epoch [2/10], Step [600/1900], d_loss: -1.8680, g_loss: 1.6900, D(x): 1.91, D(G(z)): 0.04
# Epoch [2/10], Step [700/1900], d_loss: -1.9809, g_loss: 1.9054, D(x): 2.16, D(G(z)): 0.18
# Epoch [2/10], Step [800/1900], d_loss: -1.7290, g_loss: 1.6841, D(x): 1.72, D(G(z)): -0.01
# Epoch [2/10], Step [900/1900], d_loss: -1.8641, g_loss: 0.3662, D(x): 0.21, D(G(z)): -1.65
# Epoch [2/10], Step [1000/1900], d_loss: -1.3927, g_loss: 1.8805, D(x): 2.23, D(G(z)): 0.84
# Epoch [2/10], Step [1100/1900], d_loss: -2.3773, g_loss: 1.6638, D(x): 1.79, D(G(z)): -0.59
# Epoch [2/10], Step [1200/1900], d_loss: -1.8458, g_loss: 0.0739, D(x): 0.30, D(G(z)): -1.55
# Epoch [2/10], Step [1300/1900], d_loss: -1.8494, g_loss: 0.1478, D(x): 0.25, D(G(z)): -1.60
# Epoch [2/10], Step [1400/1900], d_loss: -2.1184, g_loss: 1.4641, D(x): 1.72, D(G(z)): -0.40
# Epoch [2/10], Step [1500/1900], d_loss: -1.5570, g_loss: 0.2362, D(x): -0.16, D(G(z)): -1.72
# Epoch [2/10], Step [1600/1900], d_loss: -2.3493, g_loss: 0.7392, D(x): 1.07, D(G(z)): -1.28
# Epoch [2/10], Step [1700/1900], d_loss: -2.2767, g_loss: 0.3921, D(x): 0.82, D(G(z)): -1.46
# Epoch [2/10], Step [1800/1900], d_loss: -1.8517, g_loss: 1.7139, D(x): 1.77, D(G(z)): -0.08
# Epoch [2/10], Step [1900/1900], d_loss: -1.8031, g_loss: 0.0222, D(x): 0.24, D(G(z)): -1.56
# Saving fake_images-0003.png
# Epoch [3/10], Step [100/1900], d_loss: -2.3975, g_loss: 0.2423, D(x): 0.81, D(G(z)): -1.59
# Epoch [3/10], Step [200/1900], d_loss: -1.7691, g_loss: 0.3055, D(x): 0.28, D(G(z)): -1.49
# Epoch [3/10], Step [300/1900], d_loss: -1.5142, g_loss: 0.3295, D(x): -0.15, D(G(z)): -1.66
# Epoch [3/10], Step [400/1900], d_loss: -2.0282, g_loss: 0.0262, D(x): 0.42, D(G(z)): -1.61
# Epoch [3/10], Step [500/1900], d_loss: -2.1102, g_loss: 0.3103, D(x): 0.55, D(G(z)): -1.56
# Epoch [3/10], Step [600/1900], d_loss: -1.8493, g_loss: 0.0903, D(x): 0.37, D(G(z)): -1.48
# Epoch [3/10], Step [700/1900], d_loss: -1.2763, g_loss: 0.5041, D(x): -0.18, D(G(z)): -1.46
# Epoch [3/10], Step [800/1900], d_loss: -1.8285, g_loss: 0.4293, D(x): 0.10, D(G(z)): -1.73
# Epoch [3/10], Step [900/1900], d_loss: -1.8636, g_loss: 0.4029, D(x): 0.37, D(G(z)): -1.49
# Epoch [3/10], Step [1000/1900], d_loss: -1.8004, g_loss: 0.5896, D(x): 0.40, D(G(z)): -1.40
# Epoch [3/10], Step [1100/1900], d_loss: -1.7098, g_loss: 0.1508, D(x): 0.08, D(G(z)): -1.63
# Epoch [3/10], Step [1200/1900], d_loss: -2.0103, g_loss: -0.4201, D(x): 0.40, D(G(z)): -1.61
# Epoch [3/10], Step [1300/1900], d_loss: -1.7417, g_loss: 0.4571, D(x): 0.24, D(G(z)): -1.51
# Epoch [3/10], Step [1400/1900], d_loss: -2.1246, g_loss: 0.2394, D(x): 0.66, D(G(z)): -1.47
# Epoch [3/10], Step [1500/1900], d_loss: -1.8976, g_loss: -0.2369, D(x): 0.57, D(G(z)): -1.32
# Epoch [3/10], Step [1600/1900], d_loss: -1.8139, g_loss: -0.1301, D(x): 0.28, D(G(z)): -1.53
# Epoch [3/10], Step [1700/1900], d_loss: -1.5514, g_loss: 0.3317, D(x): -0.01, D(G(z)): -1.56
# Epoch [3/10], Step [1800/1900], d_loss: -1.6402, g_loss: -0.1772, D(x): 0.10, D(G(z)): -1.54
# Epoch [3/10], Step [1900/1900], d_loss: -1.6524, g_loss: 1.3874, D(x): 1.72, D(G(z)): 0.07
# Saving fake_images-0004.png
# Epoch [4/10], Step [100/1900], d_loss: -2.0167, g_loss: 1.4413, D(x): 1.62, D(G(z)): -0.40
# Epoch [4/10], Step [200/1900], d_loss: -1.4390, g_loss: 1.7609, D(x): 1.86, D(G(z)): 0.43
# Epoch [4/10], Step [300/1900], d_loss: -1.6215, g_loss: -0.4696, D(x): -0.11, D(G(z)): -1.73
# Epoch [4/10], Step [400/1900], d_loss: -1.5153, g_loss: -0.6092, D(x): -0.09, D(G(z)): -1.60
# Epoch [4/10], Step [500/1900], d_loss: -1.5978, g_loss: 0.2561, D(x): -0.03, D(G(z)): -1.63
# Epoch [4/10], Step [600/1900], d_loss: -1.6201, g_loss: 0.2003, D(x): -0.01, D(G(z)): -1.63
# Epoch [4/10], Step [700/1900], d_loss: -2.1454, g_loss: 1.0570, D(x): 1.02, D(G(z)): -1.12
# Epoch [4/10], Step [800/1900], d_loss: -1.5157, g_loss: 1.5746, D(x): 1.98, D(G(z)): 0.47
# Epoch [4/10], Step [900/1900], d_loss: -1.4084, g_loss: 1.4713, D(x): 1.92, D(G(z)): 0.51
# Epoch [4/10], Step [1000/1900], d_loss: -2.0456, g_loss: 0.7472, D(x): 1.26, D(G(z)): -0.78
# Epoch [4/10], Step [1100/1900], d_loss: -1.7314, g_loss: 0.3498, D(x): 0.30, D(G(z)): -1.43
# Epoch [4/10], Step [1200/1900], d_loss: -1.7836, g_loss: -0.0646, D(x): 0.27, D(G(z)): -1.52
# Epoch [4/10], Step [1300/1900], d_loss: -1.9376, g_loss: 1.5206, D(x): 1.72, D(G(z)): -0.22
# Epoch [4/10], Step [1400/1900], d_loss: -1.4093, g_loss: 1.3854, D(x): 1.75, D(G(z)): 0.34
# Epoch [4/10], Step [1500/1900], d_loss: -1.3998, g_loss: 0.3821, D(x): -0.20, D(G(z)): -1.60
# Epoch [4/10], Step [1600/1900], d_loss: -1.4426, g_loss: 0.0438, D(x): 0.02, D(G(z)): -1.43
# Epoch [4/10], Step [1700/1900], d_loss: -1.7172, g_loss: 0.2601, D(x): 0.23, D(G(z)): -1.49
# Epoch [4/10], Step [1800/1900], d_loss: -1.7498, g_loss: 1.5563, D(x): 1.43, D(G(z)): -0.32
# Epoch [4/10], Step [1900/1900], d_loss: -1.5439, g_loss: 1.2984, D(x): 1.60, D(G(z)): 0.06
# Saving fake_images-0005.png
# Epoch [5/10], Step [100/1900], d_loss: -1.8488, g_loss: -0.0514, D(x): 0.37, D(G(z)): -1.48
# Epoch [5/10], Step [200/1900], d_loss: -1.5410, g_loss: -0.1151, D(x): 0.35, D(G(z)): -1.19
# Epoch [5/10], Step [300/1900], d_loss: -1.7045, g_loss: -0.0619, D(x): 0.17, D(G(z)): -1.53
# Epoch [5/10], Step [400/1900], d_loss: -1.6905, g_loss: 0.3489, D(x): 0.45, D(G(z)): -1.24
# Epoch [5/10], Step [500/1900], d_loss: -2.1060, g_loss: 0.1210, D(x): 0.69, D(G(z)): -1.42
# Epoch [5/10], Step [600/1900], d_loss: -1.7783, g_loss: 0.0272, D(x): 0.54, D(G(z)): -1.24
# Epoch [5/10], Step [700/1900], d_loss: -1.1922, g_loss: 1.5606, D(x): 1.90, D(G(z)): 0.71
# Epoch [5/10], Step [800/1900], d_loss: -1.2829, g_loss: 1.1892, D(x): 1.97, D(G(z)): 0.69
# Epoch [5/10], Step [900/1900], d_loss: -1.6906, g_loss: 1.7447, D(x): 1.88, D(G(z)): 0.19
# Epoch [5/10], Step [1000/1900], d_loss: -1.3071, g_loss: 1.5940, D(x): 1.98, D(G(z)): 0.67
# Epoch [5/10], Step [1100/1900], d_loss: -1.2393, g_loss: 1.7261, D(x): 1.94, D(G(z)): 0.70
# Epoch [5/10], Step [1200/1900], d_loss: -1.5989, g_loss: 1.4166, D(x): 1.62, D(G(z)): 0.03
# Epoch [5/10], Step [1300/1900], d_loss: -1.3147, g_loss: 1.1231, D(x): 1.66, D(G(z)): 0.35
# Epoch [5/10], Step [1400/1900], d_loss: -2.0950, g_loss: 0.5886, D(x): 0.92, D(G(z)): -1.18
# Epoch [5/10], Step [1500/1900], d_loss: -1.5983, g_loss: 1.5308, D(x): 1.69, D(G(z)): 0.09
# Epoch [5/10], Step [1600/1900], d_loss: -1.3465, g_loss: 1.3713, D(x): 1.63, D(G(z)): 0.29
# Epoch [5/10], Step [1700/1900], d_loss: -1.9416, g_loss: -0.2769, D(x): 0.68, D(G(z)): -1.27
# Epoch [5/10], Step [1800/1900], d_loss: -1.5865, g_loss: 1.6824, D(x): 1.78, D(G(z)): 0.20
# Epoch [5/10], Step [1900/1900], d_loss: -1.6061, g_loss: 0.5102, D(x): 0.15, D(G(z)): -1.46
# Saving fake_images-0006.png
# Epoch [6/10], Step [100/1900], d_loss: -2.0081, g_loss: 0.6503, D(x): 0.70, D(G(z)): -1.30
# Epoch [6/10], Step [200/1900], d_loss: -1.5555, g_loss: 1.5625, D(x): 1.91, D(G(z)): 0.36
# Epoch [6/10], Step [300/1900], d_loss: -1.5016, g_loss: 1.5348, D(x): 1.85, D(G(z)): 0.35
# Epoch [6/10], Step [400/1900], d_loss: -1.5805, g_loss: 0.0794, D(x): 0.36, D(G(z)): -1.22
# Epoch [6/10], Step [500/1900], d_loss: -2.0238, g_loss: 1.3749, D(x): 1.49, D(G(z)): -0.54
# Epoch [6/10], Step [600/1900], d_loss: -1.8120, g_loss: 1.2315, D(x): 1.76, D(G(z)): -0.05
# Epoch [6/10], Step [700/1900], d_loss: -1.9352, g_loss: 0.5039, D(x): 0.93, D(G(z)): -1.01
# Epoch [6/10], Step [800/1900], d_loss: -1.7549, g_loss: -0.0521, D(x): 0.33, D(G(z)): -1.43
# Epoch [6/10], Step [900/1900], d_loss: -1.2501, g_loss: -0.2575, D(x): -0.29, D(G(z)): -1.54
# Epoch [6/10], Step [1000/1900], d_loss: -1.7309, g_loss: 1.3400, D(x): 1.57, D(G(z)): -0.16
# Epoch [6/10], Step [1100/1900], d_loss: -1.7763, g_loss: 0.8233, D(x): 1.18, D(G(z)): -0.60
# Epoch [6/10], Step [1200/1900], d_loss: -1.7130, g_loss: 1.6229, D(x): 1.79, D(G(z)): 0.07
# Epoch [6/10], Step [1300/1900], d_loss: -1.3841, g_loss: -0.4578, D(x): -0.06, D(G(z)): -1.44
# Epoch [6/10], Step [1400/1900], d_loss: -1.6160, g_loss: 0.6366, D(x): 0.25, D(G(z)): -1.37
# Epoch [6/10], Step [1500/1900], d_loss: -1.5843, g_loss: 1.0233, D(x): 1.14, D(G(z)): -0.44
# Epoch [6/10], Step [1600/1900], d_loss: -1.5693, g_loss: -0.3761, D(x): 0.24, D(G(z)): -1.32
# Epoch [6/10], Step [1700/1900], d_loss: -1.9082, g_loss: 1.2662, D(x): 1.52, D(G(z)): -0.39
# Epoch [6/10], Step [1800/1900], d_loss: -1.3581, g_loss: 1.2425, D(x): 1.57, D(G(z)): 0.21
# Epoch [6/10], Step [1900/1900], d_loss: -1.7174, g_loss: 1.5892, D(x): 2.07, D(G(z)): 0.35
# Saving fake_images-0007.png
# Epoch [7/10], Step [100/1900], d_loss: -1.7333, g_loss: 1.4827, D(x): 1.76, D(G(z)): 0.03
# Epoch [7/10], Step [200/1900], d_loss: -1.4606, g_loss: 1.6129, D(x): 1.76, D(G(z)): 0.30
# Epoch [7/10], Step [300/1900], d_loss: -1.7498, g_loss: 0.0250, D(x): 0.42, D(G(z)): -1.33
# Epoch [7/10], Step [400/1900], d_loss: -1.1991, g_loss: 1.4021, D(x): 2.04, D(G(z)): 0.85
# Epoch [7/10], Step [500/1900], d_loss: -1.2225, g_loss: 1.4866, D(x): 1.72, D(G(z)): 0.50
# Epoch [7/10], Step [600/1900], d_loss: -1.3105, g_loss: 0.0143, D(x): -0.28, D(G(z)): -1.59
# Epoch [7/10], Step [700/1900], d_loss: -1.9295, g_loss: 0.7108, D(x): 0.76, D(G(z)): -1.17
# Epoch [7/10], Step [800/1900], d_loss: -2.0761, g_loss: 0.9412, D(x): 1.46, D(G(z)): -0.62
# Epoch [7/10], Step [900/1900], d_loss: -1.4372, g_loss: -0.4452, D(x): -0.04, D(G(z)): -1.48
# Epoch [7/10], Step [1000/1900], d_loss: -1.6206, g_loss: -0.0283, D(x): 0.38, D(G(z)): -1.24
# Epoch [7/10], Step [1100/1900], d_loss: -1.5935, g_loss: 1.2953, D(x): 1.73, D(G(z)): 0.13
# Epoch [7/10], Step [1200/1900], d_loss: -1.6138, g_loss: 0.1073, D(x): 0.31, D(G(z)): -1.31
# Epoch [7/10], Step [1300/1900], d_loss: -1.6461, g_loss: -0.4901, D(x): -0.01, D(G(z)): -1.65
# Epoch [7/10], Step [1400/1900], d_loss: -1.4285, g_loss: -0.1585, D(x): -0.11, D(G(z)): -1.53
# Epoch [7/10], Step [1500/1900], d_loss: -1.5844, g_loss: 1.3725, D(x): 1.75, D(G(z)): 0.16
# Epoch [7/10], Step [1600/1900], d_loss: -1.7115, g_loss: 0.0711, D(x): 0.25, D(G(z)): -1.46
# Epoch [7/10], Step [1700/1900], d_loss: -1.6514, g_loss: -0.2352, D(x): 0.22, D(G(z)): -1.43
# Epoch [7/10], Step [1800/1900], d_loss: -1.2644, g_loss: 1.2922, D(x): 2.04, D(G(z)): 0.78
# Epoch [7/10], Step [1900/1900], d_loss: -1.6959, g_loss: 1.4662, D(x): 1.60, D(G(z)): -0.10
# Saving fake_images-0008.png
# Epoch [8/10], Step [100/1900], d_loss: -1.2730, g_loss: 0.2869, D(x): 0.04, D(G(z)): -1.24
# Epoch [8/10], Step [200/1900], d_loss: -1.4618, g_loss: 1.4227, D(x): 1.63, D(G(z)): 0.16
# Epoch [8/10], Step [300/1900], d_loss: -1.6676, g_loss: 1.3563, D(x): 1.49, D(G(z)): -0.18
# Epoch [8/10], Step [400/1900], d_loss: -1.2754, g_loss: 1.3900, D(x): 2.08, D(G(z)): 0.80
# Epoch [8/10], Step [500/1900], d_loss: -1.9344, g_loss: 0.2985, D(x): 0.86, D(G(z)): -1.08
# Epoch [8/10], Step [600/1900], d_loss: -1.3816, g_loss: 1.5976, D(x): 1.74, D(G(z)): 0.35
# Epoch [8/10], Step [700/1900], d_loss: -1.5567, g_loss: 0.0269, D(x): -0.00, D(G(z)): -1.56
# Epoch [8/10], Step [800/1900], d_loss: -1.2515, g_loss: -0.5758, D(x): -0.06, D(G(z)): -1.31
# Epoch [8/10], Step [900/1900], d_loss: -1.6736, g_loss: -0.0244, D(x): 0.21, D(G(z)): -1.46
# Epoch [8/10], Step [1000/1900], d_loss: -1.4912, g_loss: -0.1787, D(x): 0.18, D(G(z)): -1.31
# Epoch [8/10], Step [1100/1900], d_loss: -1.4889, g_loss: 0.1364, D(x): 0.43, D(G(z)): -1.05
# Epoch [8/10], Step [1200/1900], d_loss: -1.3274, g_loss: -0.1774, D(x): -0.02, D(G(z)): -1.34
# Epoch [8/10], Step [1300/1900], d_loss: -1.2760, g_loss: 1.6014, D(x): 2.02, D(G(z)): 0.75
# Epoch [8/10], Step [1400/1900], d_loss: -1.3020, g_loss: 0.6185, D(x): -0.22, D(G(z)): -1.52
# Epoch [8/10], Step [1500/1900], d_loss: -1.6006, g_loss: 1.5036, D(x): 1.84, D(G(z)): 0.24
# Epoch [8/10], Step [1600/1900], d_loss: -1.1194, g_loss: 1.1324, D(x): 1.82, D(G(z)): 0.70
# Epoch [8/10], Step [1700/1900], d_loss: -1.2333, g_loss: 1.5514, D(x): 2.13, D(G(z)): 0.89
# Epoch [8/10], Step [1800/1900], d_loss: -1.1543, g_loss: 1.1912, D(x): 2.03, D(G(z)): 0.88
# Epoch [8/10], Step [1900/1900], d_loss: -0.9173, g_loss: 1.0932, D(x): 2.02, D(G(z)): 1.10
# Saving fake_images-0009.png
# Epoch [9/10], Step [100/1900], d_loss: -1.6285, g_loss: -0.0952, D(x): 0.32, D(G(z)): -1.31
# Epoch [9/10], Step [200/1900], d_loss: -1.7867, g_loss: 0.9331, D(x): 1.23, D(G(z)): -0.56
# Epoch [9/10], Step [300/1900], d_loss: -1.3468, g_loss: 0.9610, D(x): 1.09, D(G(z)): -0.25
# Epoch [9/10], Step [400/1900], d_loss: -1.4555, g_loss: 0.5619, D(x): 0.64, D(G(z)): -0.82
# Epoch [9/10], Step [500/1900], d_loss: -1.2926, g_loss: -0.1621, D(x): 0.10, D(G(z)): -1.19
# Epoch [9/10], Step [600/1900], d_loss: -1.4923, g_loss: 1.1214, D(x): 1.39, D(G(z)): -0.10
# Epoch [9/10], Step [700/1900], d_loss: -1.6438, g_loss: 1.3061, D(x): 1.66, D(G(z)): 0.01
# Epoch [9/10], Step [800/1900], d_loss: -1.6204, g_loss: 1.2164, D(x): 1.50, D(G(z)): -0.12
# Epoch [9/10], Step [900/1900], d_loss: -1.3317, g_loss: -0.2803, D(x): -0.01, D(G(z)): -1.34
# Epoch [9/10], Step [1000/1900], d_loss: -1.4433, g_loss: -0.2731, D(x): 0.04, D(G(z)): -1.41
# Epoch [9/10], Step [1100/1900], d_loss: -1.9340, g_loss: 0.4843, D(x): 0.96, D(G(z)): -0.97
# Epoch [9/10], Step [1200/1900], d_loss: -1.6187, g_loss: 1.6420, D(x): 1.82, D(G(z)): 0.20
# Epoch [9/10], Step [1300/1900], d_loss: -1.5031, g_loss: 0.0907, D(x): 0.63, D(G(z)): -0.87
# Epoch [9/10], Step [1400/1900], d_loss: -1.2354, g_loss: 1.1747, D(x): 1.78, D(G(z)): 0.55
# Epoch [9/10], Step [1500/1900], d_loss: -1.2425, g_loss: 0.4088, D(x): -0.13, D(G(z)): -1.37
# Epoch [9/10], Step [1600/1900], d_loss: -1.4126, g_loss: -0.1595, D(x): 0.30, D(G(z)): -1.12
# Epoch [9/10], Step [1700/1900], d_loss: -1.4863, g_loss: -0.0783, D(x): 0.08, D(G(z)): -1.41
# Epoch [9/10], Step [1800/1900], d_loss: -1.2393, g_loss: -0.2007, D(x): -0.21, D(G(z)): -1.45
# Epoch [9/10], Step [1900/1900], d_loss: -1.3658, g_loss: 1.3489, D(x): 1.68, D(G(z)): 0.31
# Saving fake_images-0010.png
# Wall time: 1h 33min 46s

# %%
x_axis = np.linspace(-1, 1, len(d_losses), endpoint=True)
x_axis1 = np.linspace(-1, 1, len(g_losses), endpoint=True)
plt.plot(x_axis, d_losses, label='D_Loss')
plt.plot(x_axis1, g_losses, label='G_Loss')
plt.legend(loc='best')

# %%
Image('./samples/fake_images-0000.png')

# %%
Image('./samples/fake_images-0002.png')

# %%
Image('./samples/fake_images-0006.png')

# %%
Image('./samples/fake_images-0010.png')
